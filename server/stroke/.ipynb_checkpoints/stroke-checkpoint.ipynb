# %%
import numpy as np  
import pandas as pd

# %%
df = pd.read_csv('stroke_prediction_dataset.csv')
df
# Out:
#        Patient ID       Patient Name  Age  Gender  Hypertension  \
# 0           18153    Mamooty Khurana   56    Male             0
# 1           62749  Kaira Subramaniam   80    Male             0
# 2           32145      Dhanush Balan   26    Male             1
# 3            6154        Ivana Baral   73    Male             0
# 4           48973  Darshit Jayaraman   51    Male             1
# ...           ...                ...  ...     ...           ...
# 14995       13981          Keya Iyer   88  Female             1
# 14996       87707       Anahita Virk   47  Female             0
# 14997       33174         Ivana Kaur   35    Male             0
# 14998       22343        Anvi Mannan   73    Male             0
# 14999       11066      Gokul Trivedi   64  Female             0
#
#        Heart Disease Marital Status       Work Type Residence Type  \
# 0                  1        Married   Self-employed          Rural
# ...

# %%
df.drop(columns=['Patient ID','Patient Name'], inplace=True)
df
# Out:
#        Age  Gender  Hypertension  Heart Disease Marital Status  \
# 0       56    Male             0              1        Married
# 1       80    Male             0              0         Single
# 2       26    Male             1              1        Married
# 3       73    Male             0              0        Married
# 4       51    Male             1              1       Divorced
# ...    ...     ...           ...            ...            ...
# 14995   88  Female             1              1       Divorced
# 14996   47  Female             0              0        Married
# 14997   35    Male             0              0        Married
# 14998   73    Male             0              0         Single
# 14999   64  Female             0              0         Single
#
#             Work Type Residence Type  Average Glucose Level  \
# 0       Self-employed          Rural                 130.91
# 1       Self-employed          Urban                 183.73
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Hypertension', 'Heart Disease', 'Marital Status',
#        'Work Type', 'Residence Type', 'Average Glucose Level',
#        'Body Mass Index (BMI)', 'Smoking Status', 'Alcohol Intake',
#        'Physical Activity', 'Stroke History', 'Family History of Stroke',
#        'Dietary Habits', 'Stress Levels', 'Blood Pressure Levels',
#        'Cholesterol Levels', 'Symptoms', 'Diagnosis'],
#       dtype='object')

# %%
# Detect non-numerical columns in the dataframe
non_numerical_columns = df.select_dtypes(include=['object']).columns
non_numerical_columns = list(non_numerical_columns)
non_numerical_columns.remove('Diagnosis')
non_numerical_columns
# Out:
# ['Gender',
#  'Marital Status',
#  'Work Type',
#  'Residence Type',
#  'Smoking Status',
#  'Alcohol Intake',
#  'Physical Activity',
#  'Family History of Stroke',
#  'Dietary Habits',
#  'Blood Pressure Levels',
#  'Cholesterol Levels',
#  'Symptoms']

# %%
numerical_columns = df.columns.difference(non_numerical_columns)
numerical_columns
# Out:
# Index(['Age', 'Average Glucose Level', 'Body Mass Index (BMI)', 'Diagnosis',
#        'Heart Disease', 'Hypertension', 'Stress Levels', 'Stroke History'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
ohe = OneHotEncoder()
le = LabelEncoder()

# %%
df = ohe.fit_transform(df)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = ohe.fit_transform(df, sparse = False)
#       2 df
#
# File c:\Users\pubg3\.conda\envs\tf\lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File c:\Users\pubg3\.conda\envs\tf\lib\site-packages\sklearn\base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
# ...
