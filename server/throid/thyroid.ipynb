# %%
import numpy as np  
import pandas as pd

# %%
df = pd.read_csv('thyroidDF.csv')
# Out:
#       age sex on_thyroxine query_on_thyroxine on_antithyroid_meds sick  \
# 0      29   F            f                  f                   f    f
# 1      29   F            f                  f                   f    f
# 2      41   F            f                  f                   f    f
# 3      36   F            f                  f                   f    f
# 4      32   F            f                  f                   f    f
# ...   ...  ..          ...                ...                 ...  ...
# 9167   56   M            f                  f                   f    f
# 9168   22   M            f                  f                   f    f
# 9169   69   M            f                  f                   f    f
# 9170   47   F            f                  f                   f    f
# 9171   31   M            f                  f                   f    f
#
#      pregnant thyroid_surgery I131_treatment query_hypothyroid  ...    TT4  \
# 0           f               f              f                 t  ...    NaN
# 1           f               f              f                 f  ...  128.0
# 2           f               f              f                 f  ...    NaN
# 3           f               f              f                 f  ...    NaN
# 4           f               f              f                 f  ...    NaN
# ...       ...             ...            ...               ...  ...    ...
# 9167        f               f              f                 f  ...   64.0
# 9168        f               f              f                 f  ...   91.0
# 9169        f               f              f                 f  ...  113.0
# 9170        f               f              f                 f  ...   75.0
# 9171        f               f              f                 t  ...   66.0
#
#      T4U_measured   T4U FTI_measured   FTI TBG_measured   TBG  \
# 0               f   NaN            f   NaN            f   NaN
# 1               f   NaN            f   NaN            f   NaN
# 2               f   NaN            f   NaN            t  11.0
# 3               f   NaN            f   NaN            t  26.0
# 4               f   NaN            f   NaN            t  36.0
# ...           ...   ...          ...   ...          ...   ...
# 9167            t  0.83            t  77.0            f   NaN
# 9168            t  0.92            t  99.0            f   NaN
# 9169            t  1.27            t  89.0            f   NaN
# 9170            t  0.85            t  88.0            f   NaN
# 9171            t  1.02            t  65.0            f   NaN
#
#       referral_source target  patient_id
# 0               other      -   840801013
# 1               other      -   840801014
# 2               other      -   840801042
# 3               other      -   840803046
# 4               other      S   840803047
# ...               ...    ...         ...
# 9167              SVI      -   870119022
# 9168              SVI      -   870119023
# 9169              SVI      I   870119025
# 9170            other      -   870119027
# 9171            other      -   870119035
#
# [9172 rows x 31 columns]

# %%
df.nunique()
# Out:
# age                     100
# sex                       2
# on_thyroxine              2
# query_on_thyroxine        2
# on_antithyroid_meds       2
# sick                      2
# pregnant                  2
# thyroid_surgery           2
# I131_treatment            2
# query_hypothyroid         2
# query_hyperthyroid        2
# lithium                   2
# goitre                    2
# tumor                     2
# hypopituitary             2
# psych                     2
# TSH_measured              2
# TSH                     369
# T3_measured               2
# T3                       85
# TT4_measured              2
# TT4                     287
# T4U_measured              2
# T4U                     176
# FTI_measured              2
# FTI                     323
# TBG_measured              2
# TBG                      66
# referral_source           6
# target                   32
# patient_id             9172
# dtype: int64

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.corr()
#
# File c:\Users\pubg3\.conda\envs\tf\lib\site-packages\pandas\core\frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\pubg3\.conda\envs\tf\lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\pubg3\.conda\envs\tf\lib\site-packages\pandas\core\internals\managers.py:1692, in BlockManager.as_array(self, dtype, copy, na_value)
#    1690         arr.flags.writeable = False
#    1691 else:
# -> 1692     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1693     # The underlying data was copied within _interleave, so no need
#    1694     # to further copy if copy=True or setting na_value
#    1696 if na_value is lib.no_default:
#
# File c:\Users\pubg3\.conda\envs\tf\lib\site-packages\pandas\core\internals\managers.py:1751, in BlockManager._interleave(self, dtype, na_value)
#    1749     else:
#    1750         arr = blk.get_values(dtype)
# -> 1751     result[rl.indexer] = arr
#    1752     itemmask[rl.indexer] = 1
#    1754 if not itemmask.all():
#
# ValueError: could not convert string to float: 'F'

# %%
df.drop(columns=['Patient ID','Patient Name'], inplace=True)
df
# Out:
#        Age  Gender  Hypertension  Heart Disease Marital Status  \
# 0       56    Male             0              1        Married
# 1       80    Male             0              0         Single
# 2       26    Male             1              1        Married
# 3       73    Male             0              0        Married
# 4       51    Male             1              1       Divorced
# ...    ...     ...           ...            ...            ...
# 14995   88  Female             1              1       Divorced
# 14996   47  Female             0              0        Married
# 14997   35    Male             0              0        Married
# 14998   73    Male             0              0         Single
# 14999   64  Female             0              0         Single
#
#             Work Type Residence Type  Average Glucose Level  \
# 0       Self-employed          Rural                 130.91
# 1       Self-employed          Urban                 183.73
# 2        Never Worked          Rural                 189.00
# 3        Never Worked          Urban                 185.29
# 4       Self-employed          Urban                 177.34
# ...               ...            ...                    ...
# 14995   Self-employed          Urban                 160.22
# 14996         Private          Urban                 107.58
# 14997  Government Job          Rural                 134.90
# 14998   Self-employed          Urban                 169.42
# 14999    Never Worked          Urban                 186.88
#
#        Body Mass Index (BMI)    Smoking Status    Alcohol Intake  \
# 0                      22.37        Non-smoker    Social Drinker
# 1                      32.57        Non-smoker             Never
# 2                      20.32   Formerly Smoked            Rarely
# 3                      27.50        Non-smoker  Frequent Drinker
# 4                      29.06  Currently Smokes            Rarely
# ...                      ...               ...               ...
# 14995                  39.73  Currently Smokes    Social Drinker
# 14996                  22.17        Non-smoker             Never
# 14997                  26.38        Non-smoker            Rarely
# 14998                  28.32        Non-smoker             Never
# 14999                  39.30  Currently Smokes            Rarely
#
#       Physical Activity  Stroke History Family History of Stroke  \
# 0              Moderate               0                      Yes
# 1                   Low               0                       No
# 2                  High               0                      Yes
# 3              Moderate               0                       No
# 4                   Low               0                      Yes
# ...                 ...             ...                      ...
# 14995              High               0                       No
# 14996               Low               1                       No
# 14997              High               1                       No
# 14998              High               0                      Yes
# 14999          Moderate               0                       No
#
#       Dietary Habits  Stress Levels Blood Pressure Levels Cholesterol Levels  \
# 0              Vegan           3.48               140/108  HDL: 68, LDL: 133
# 1              Paleo           1.73                146/91   HDL: 63, LDL: 70
# 2              Paleo           7.31                154/97   HDL: 59, LDL: 95
# 3              Paleo           5.35                174/81  HDL: 70, LDL: 137
# 4        Pescatarian           6.84                121/95   HDL: 65, LDL: 68
# ...              ...            ...                   ...                ...
# 14995          Paleo           1.12                171/92  HDL: 44, LDL: 153
# 14996    Gluten-Free           1.47                155/71  HDL: 35, LDL: 183
# 14997          Paleo           0.51               121/110  HDL: 57, LDL: 159
# 14998          Paleo           1.53                157/74   HDL: 79, LDL: 91
# 14999          Vegan           4.57                133/81  HDL: 78, LDL: 179
#
#                                                 Symptoms  Diagnosis
# 0                          Difficulty Speaking, Headache     Stroke
# 1        Loss of Balance, Headache, Dizziness, Confusion     Stroke
# 2                                    Seizures, Dizziness     Stroke
# 3      Seizures, Blurred Vision, Severe Fatigue, Head...  No Stroke
# 4                                    Difficulty Speaking     Stroke
# ...                                                  ...        ...
# 14995                                                NaN  No Stroke
# 14996                                Difficulty Speaking  No Stroke
# 14997      Difficulty Speaking, Severe Fatigue, Headache     Stroke
# 14998  Severe Fatigue, Numbness, Confusion, Dizziness...  No Stroke
# 14999                                           Headache     Stroke
#
# [15000 rows x 20 columns]

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['Gender', 'Marital Status', 'Work Type', 'Residence Type',
#        'Smoking Status', 'Alcohol Intake', 'Physical Activity',
#        'Family History of Stroke', 'Dietary Habits', 'Blood Pressure Levels',
#        'Cholesterol Levels', 'Symptoms', 'Diagnosis'],
#       dtype='object')

# %%
for i in categorical_columns:
    print(f"{df[i].nunique()} unique values in {i} column")
# Out:
# 2 unique values in Gender column
# 3 unique values in Marital Status column
# 4 unique values in Work Type column
# 2 unique values in Residence Type column
# 3 unique values in Smoking Status column
# 4 unique values in Alcohol Intake column
# 3 unique values in Physical Activity column
# 2 unique values in Family History of Stroke column
# 7 unique values in Dietary Habits column
# 4458 unique values in Blood Pressure Levels column
# 5952 unique values in Cholesterol Levels column
# 5786 unique values in Symptoms column
# 2 unique values in Diagnosis column

# %%
categorical_columns_with_100_unique_values = [i for i in categorical_columns if df[i].nunique() > 100]
categorical_columns = [i for i in categorical_columns if df[i].nunique() < 100]

categorical_columns_with_100_unique_values
# Out:
# ['Blood Pressure Levels', 'Cholesterol Levels', 'Symptoms']

# %%
categorical_columns.remove('Diagnosis')
categorical_columns
# Out:
# ['Gender',
#  'Marital Status',
#  'Work Type',
#  'Residence Type',
#  'Smoking Status',
#  'Alcohol Intake',
#  'Physical Activity',
#  'Family History of Stroke',
#  'Dietary Habits']

# %%
df.drop(columns=categorical_columns_with_100_unique_values, inplace=True)
df.shape
# Out:
# (15000, 17)

# %%
x_df = df[df.columns[:-1]]
y_df = df[df.columns[-1]]

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
label_encoder = LabelEncoder()
onehot_encoder = OneHotEncoder()

# %%
x_encoded_array = onehot_encoder.fit_transform(x_df[categorical_columns]).toarray()
x_encoded_df = pd.DataFrame(x_encoded_array, columns=onehot_encoder.get_feature_names_out(categorical_columns))
y_label_encoder = label_encoder.fit_transform(y_df)

x_encoded_df.shape
# Out:
# (15000, 30)

# %%
y_encoded = label_encoder.fit_transform(y_df)
y_encoded.shape
# Out:
# (15000,)

# %%
from matplotlib import scale
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
x_encoded_df_scaled = scale.fit_transform(x_encoded_df)
x_encoded_df_scaled = pd.DataFrame(x_encoded_df_scaled, columns=x_encoded_df.columns)
x_encoded_df_scaled
# Out:
#        Gender_Female  Gender_Male  Marital Status_Divorced  \
# 0          -0.983864     0.983864                -0.704987
# 1          -0.983864     0.983864                -0.704987
# 2          -0.983864     0.983864                -0.704987
# 3          -0.983864     0.983864                -0.704987
# 4          -0.983864     0.983864                 1.418467
# ...              ...          ...                      ...
# 14995       1.016401    -1.016401                 1.418467
# 14996       1.016401    -1.016401                -0.704987
# 14997      -0.983864     0.983864                -0.704987
# 14998      -0.983864     0.983864                -0.704987
# 14999       1.016401    -1.016401                -0.704987
#
#        Marital Status_Married  Marital Status_Single  \
# 0                    1.443566               -0.72372
# 1                   -0.692729                1.38175
# 2                    1.443566               -0.72372
# 3                    1.443566               -0.72372
# 4                   -0.692729               -0.72372
# ...                       ...                    ...
# 14995               -0.692729               -0.72372
# 14996                1.443566               -0.72372
# 14997                1.443566               -0.72372
# 14998               -0.692729                1.38175
# 14999               -0.692729                1.38175
#
#        Work Type_Government Job  Work Type_Never Worked  Work Type_Private  \
# 0                     -0.573245               -0.559076          -0.588950
# 1                     -0.573245               -0.559076          -0.588950
# 2                     -0.573245                1.788667          -0.588950
# 3                     -0.573245                1.788667          -0.588950
# 4                     -0.573245               -0.559076          -0.588950
# ...                         ...                     ...                ...
# 14995                 -0.573245               -0.559076          -0.588950
# 14996                 -0.573245               -0.559076           1.697938
# 14997                  1.744456               -0.559076          -0.588950
# 14998                 -0.573245               -0.559076          -0.588950
# 14999                 -0.573245                1.788667          -0.588950
#
#        Work Type_Self-employed  Residence Type_Rural  ...  \
# 0                     1.700309              0.996141  ...
# 1                     1.700309             -1.003874  ...
# 2                    -0.588128              0.996141  ...
# 3                    -0.588128             -1.003874  ...
# 4                     1.700309             -1.003874  ...
# ...                        ...                   ...  ...
# 14995                 1.700309             -1.003874  ...
# 14996                -0.588128             -1.003874  ...
# 14997                -0.588128              0.996141  ...
# 14998                 1.700309             -1.003874  ...
# 14999                -0.588128             -1.003874  ...
#
#        Physical Activity_Moderate  Family History of Stroke_No  \
# 0                        1.414638                    -0.987808
# 1                       -0.706895                     1.012343
# 2                       -0.706895                    -0.987808
# 3                        1.414638                     1.012343
# 4                       -0.706895                    -0.987808
# ...                           ...                          ...
# 14995                   -0.706895                     1.012343
# 14996                   -0.706895                     1.012343
# 14997                   -0.706895                     1.012343
# 14998                   -0.706895                    -0.987808
# 14999                    1.414638                     1.012343
#
#        Family History of Stroke_Yes  Dietary Habits_Gluten-Free  \
# 0                          0.987808                   -0.399892
# 1                         -1.012343                   -0.399892
# 2                          0.987808                   -0.399892
# 3                         -1.012343                   -0.399892
# 4                          0.987808                   -0.399892
# ...                             ...                         ...
# 14995                     -1.012343                   -0.399892
# 14996                     -1.012343                    2.500677
# 14997                     -1.012343                   -0.399892
# 14998                      0.987808                   -0.399892
# 14999                     -1.012343                   -0.399892
#
#        Dietary Habits_Keto  Dietary Habits_Non-Vegetarian  \
# 0                -0.407375                      -0.408375
# 1                -0.407375                      -0.408375
# 2                -0.407375                      -0.408375
# 3                -0.407375                      -0.408375
# 4                -0.407375                      -0.408375
# ...                    ...                            ...
# 14995            -0.407375                      -0.408375
# 14996            -0.407375                      -0.408375
# 14997            -0.407375                      -0.408375
# 14998            -0.407375                      -0.408375
# 14999            -0.407375                      -0.408375
#
#        Dietary Habits_Paleo  Dietary Habits_Pescatarian  Dietary Habits_Vegan  \
# 0                 -0.413694                   -0.404143              2.421774
# 1                  2.417243                   -0.404143             -0.412920
# 2                  2.417243                   -0.404143             -0.412920
# 3                  2.417243                   -0.404143             -0.412920
# 4                 -0.413694                    2.474370             -0.412920
# ...                     ...                         ...                   ...
# 14995              2.417243                   -0.404143             -0.412920
# 14996             -0.413694                   -0.404143             -0.412920
# 14997              2.417243                   -0.404143             -0.412920
# 14998              2.417243                   -0.404143             -0.412920
# 14999             -0.413694                   -0.404143              2.421774
#
#        Dietary Habits_Vegetarian
# 0                       -0.41126
# 1                       -0.41126
# 2                       -0.41126
# 3                       -0.41126
# 4                       -0.41126
# ...                          ...
# 14995                   -0.41126
# 14996                   -0.41126
# 14997                   -0.41126
# 14998                   -0.41126
# 14999                   -0.41126
#
# [15000 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(x_encoded_df_scaled, y_encoded, test_size=0.33, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((10050, 30), (4950, 30), (10050,), (4950,))

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier


rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train,y_train)
rf_pred_x_encoded_test = rf.predict(X_test)
accuracy_score(y_test, rf_pred_x_encoded_test)
# Out:
# 0.49656565656565654

# %%
from sklearn.linear_model import LogisticRegression


rf = LogisticRegression()
rf.fit(X_train,y_train)
rf_pred_x_encoded_test = rf.predict(X_test)
accuracy_score(y_test, rf_pred_x_encoded_test)
# Out:
# 0.503030303030303
